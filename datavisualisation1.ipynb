# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('student.csv')

# %%
df
# Out:
#   student-name  marks  age     contact  study-hours
# 0       shreya     90   19  7889786867           10
# 1      avighna     89   18  7869586747            9
# 2        nidhi     70   20  8769754756            8
# 3        nisha    100   21  9878675678            8

# %%
print(df)
plt.title('pie chart of student study hours')
plt.pie(df.iloc[0:,4],labels=df.iloc[0:,0],autopct='%.1f%%',shadow=True) 
plt.show()
plt.title('pie chart of visualization of student age difference')
plt.pie(df.iloc[0:,2],labels=df.iloc[0:,0],autopct='%.1f%%',shadow=True) 
plt.show()
# Out:
#   student-name  marks  age     contact  study-hours
# 0       shreya     90   19  7889786867           10
# 1      avighna     89   18  7869586747            9
# 2        nidhi     70   20  8769754756            8
# 3        nisha    100   21  9878675678            8
