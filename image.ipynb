# %%
import sys
import cv2
from google.colab.patches import cv2_imshow

# %%
 # version
  print(cv2.__version__)
# Out:
# 3.4.3

# %%
# image name as first argument
#data=sys.argv[1]

# %%
# image read
img=cv2.imread('dog.jpg',1) 
img1=cv2.imread('dog.jpg',0) #loading image in a colored format --original image
print(img)
# Out:
# [[[161 174 190]
#   [162 175 191]
#   [163 176 192]
#   ...
#   [203 204 208]
#   [203 204 208]
#   [203 204 208]]
#
#  [[161 174 190]
#   [162 175 191]
#   [163 176 192]
#   ...
#   [203 204 208]
#   [203 204 208]
#   [203 204 208]]
#
#  [[162 175 191]
#   [162 175 191]
#   [163 176 192]
#   ...
#   [203 204 208]
#   [203 204 208]
#   [203 204 208]]
#
#  ...
#
#  [[153 167 185]
#   [155 169 187]
#   [156 170 188]
#   ...
#   [160 177 204]
#   [160 177 204]
#   [160 177 204]]
#
#  [[153 167 185]
#   [154 168 186]
#   [156 170 188]
#   ...
#   [160 177 204]
#   [160 177 204]
#   [160 177 204]]
#
#  [[152 166 184]
#   [154 168 186]
#   [155 169 187]
#   ...
#   [160 177 204]
#   [160 177 204]
#   [160 177 204]]]

# %%
#shape
print(img.shape)
# Out:
# (734, 1100, 3)

# %%
# height ,width ,color channel
#to show the image
cv2_imshow(img)
cv2_imshow(img-50)
cv2_imshow(img[0:200,0:600]+100)
cv2_imshow(img/2)
cv2_imshow(img1)

cv2_waitKey(0) # holding window for infinite time
# Out:
# <PIL.Image.Image image mode=RGB size=1100x734 at 0x7FC55FEC0A20>
# <PIL.Image.Image image mode=RGB size=1100x734 at 0x7FC55FEC0B00>
# <PIL.Image.Image image mode=RGB size=600x200 at 0x7FC55FEC09B0>
# <PIL.Image.Image image mode=RGB size=1100x734 at 0x7FC55FEC0A20>
# <PIL.Image.Image image mode=L size=1100x734 at 0x7FC55FEC09B0>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-9283ee471e28> in <module>()
#       5 cv2_imshow(img1)
#       6
# ----> 7 cv2_waitKey(0) # holding window for infinite time
#
# NameError: name 'cv2_waitKey' is not defined

# %%
cv2.imwrite('newdog.jpg',img1)
# Out:
# True
